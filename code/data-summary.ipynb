# %%
import pandas as pd

# %%
# Reading medal/athletes per NOC data
medals = pd.read_csv('../output/medals-data.csv')

# %%
# Reading medals list
medal_list = pd.read_csv('../output/medal-list.csv')

# %%
medal_list['unique_event'] = medal_list.Year.astype(str) + medal_list.Event

# %%
for event in medal_list.unique_event.unique():

    subset = medal_list[medal_list.unique_event == event]
    countries = ['USA', 'RUS', 'CHN']
    if all([True if country in subset.NOC.unique() else False for country in countries ]):
        display(subset)
# Out:
#      Sex           Team  NOC        Games  Year  Season            City  \
# 1596   F  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 4234   F          China  CHN  2016 Summer  2016  Summer  Rio de Janeiro
# 8146   F         Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro
#
#            Sport                               Event   Medal  \
# 1596  Gymnastics  Gymnastics Women's Team All-Around    Gold
# 4234  Gymnastics  Gymnastics Women's Team All-Around  Bronze
# 8146  Gymnastics  Gymnastics Women's Team All-Around  Silver
#
#                                 unique_event
# 1596  2016Gymnastics Women's Team All-Around
# 4234  2016Gymnastics Women's Team All-Around
# 8146  2016Gymnastics Women's Team All-Around
#      Sex           Team  NOC        Games  Year  Season    City   Sport  \
# 3929   M  United States  USA  2012 Summer  2012  Summer  London  Diving
# 7106   M         Russia  RUS  2012 Summer  2012  Summer  London  Diving
# ...

# %%
subset
# Out:
#       Sex           Team  NOC        Games  Year  Season       City  \
# 14877   M    Indonesia-1  INA  1992 Summer  1992  Summer  Barcelona
# 14883   M  South Korea-1  KOR  1992 Summer  1992  Summer  Barcelona
# 14888   M        China-2  CHN  1992 Summer  1992  Summer  Barcelona
# 14901   M     Malaysia-2  MAS  1992 Summer  1992  Summer  Barcelona
#
#            Sport                    Event   Medal                 unique_event
# 14877  Badminton  Badminton Men's Doubles  Silver  1992Badminton Men's Doubles
# 14883  Badminton  Badminton Men's Doubles    Gold  1992Badminton Men's Doubles
# 14888  Badminton  Badminton Men's Doubles  Bronze  1992Badminton Men's Doubles
# 14901  Badminton  Badminton Men's Doubles  Bronze  1992Badminton Men's Doubles

# %%
countries = ['AZE', 'CHN', 'JPN']

# %%
[True if country in subset.NOC.tolist() else False for country in countries ]
# Out:
# [False, True, False]

# %%
medal_list[(medal_list.unique_event
# Out:
#       Sex           Team  NOC        Games  Year  Season            City  \
# 56      M         Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro
# 57      M         Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro
# 58      M         Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro
# 1377    M         Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro
# 1595    F  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 1596    F  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 1597    F  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 1598    F  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 1599    F  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 3567    M          China  CHN  2016 Summer  2016  Summer  Rio de Janeiro
# 4234    F          China  CHN  2016 Summer  2016  Summer  Rio de Janeiro
# 5270    M        Germany  GER  2016 Summer  2016  Summer  Rio de Janeiro
# ...
